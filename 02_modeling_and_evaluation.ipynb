# %% [markdown]
# # Notebook 02: Modeling and Evaluation
#
# Train and compare ARIMA, Prophet, Random Forest, and LSTM on the NHS A&E dataset.

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))

from run_pipeline import main

main()

# %%
TABLE_DIR = PROJECT_ROOT / 'outputs' / 'tables'
comparison = pd.read_csv(TABLE_DIR / 'model_comparison.csv')
dm = pd.read_csv(TABLE_DIR / 'diebold_mariano_tests.csv')
fi = pd.read_csv(TABLE_DIR / 'feature_importance.csv')

display(comparison)
display(dm)
display(fi.head(10))

# %%
from IPython.display import Image, display
FIG_DIR = PROJECT_ROOT / 'outputs' / 'figures'
for fig in sorted(FIG_DIR.glob('*.png')):
    print(fig.name)
    display(Image(filename=str(fig)))
